# %% [markdown]
# Centro de Inovação em Inteligência Artificial para a Saúde da UFMG
#
# **Curso de Introdução à Análise de Dados em Saúde com Python**
#
# **Prof. Juliano Gaspar** - Faculdade de Medicina da UFMG
#
# Mais informações: https://ciia-saude.medicina.ufmg.br/

# %% [markdown]
# ## **Estatística Inferencial**

# %%
# importar as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from google.colab import files

import scipy.stats as stats
import statsmodels.stats as stsmodels
import statsmodels.stats.contingency_tables as stsmct

# %% [markdown]
# # Abrir o arquivo

# %%
# Endereço do arquivo com a base de dados
arquivo = 'https://ftp.medicina.ufmg.br/cursosciia/iads/BD_PARTOS.xlsx'

# Ler o arquivo
dados = pd.read_excel(arquivo)
dados
# Out:
#       Unnamed: 0 DT_INTERNACAO    DT_ALTA  DURACAO_INT  GESTACOES  PARTOS  \
# 0              0    2014-01-20 2014-01-21            1          2     1.0
# 1              1    2014-05-21 2014-05-22            1          1     0.0
# 2              2    2014-04-13 2014-04-14            1          2     1.0
# 3              3    2013-12-04 2013-12-05            1          2     1.0
# 4              4    2013-12-05 2013-12-06            1          1     0.0
# ...          ...           ...        ...          ...        ...     ...
# 1703        1703    2014-07-05 2014-08-12           38          2     1.0
# 1704        1704    2014-04-25 2014-06-10           46          2     1.0
# 1705        1705    2013-11-04 2013-12-22           48          2     1.0
# 1706        1706    2013-10-04 2013-11-28           55          3     0.0
# 1707        1707    2014-03-12 2014-05-14           63          3     2.0
#
#       IG_OBSTETRA  IG_PEDIATRA ALTO_RISCO     TIPO_PARTO  ...       IG_TERMO  \
# 0            38.0         38.0        Sim   Parto Normal  ...  Termo-precoce
# 1            36.0         36.0        Sim   Parto Normal  ...      Prematuro
# 2            39.0         39.0        Não   Parto Normal  ...          Termo
# 3            41.0         41.0        Não   Parto Normal  ...          Termo
# 4            36.0         36.0        Não   Parto Normal  ...      Prematuro
# ...           ...          ...        ...            ...  ...            ...
# 1703         38.0         38.0        Não   Parto Normal  ...  Termo-precoce
# 1704         29.0         34.0        Sim  Parto Cesáreo  ...      Prematuro
# 1705         26.0         32.0        Sim  Parto Cesáreo  ...      Prematuro
# 1706         27.0         34.0        Sim  Parto Cesáreo  ...      Prematuro
# 1707         39.0         39.0        Não   Parto Normal  ...          Termo
#
#      HOUVE_CESAREA  HOUVE_LACERACAO HOUVE_CM   PARIDADE PESO_VIAVEIS PESO_US  \
# 0              Não              Não      Sim  Primípara       3590.0  2590.0
# 1              Não              Não      Não   Nulípara       2660.0  1660.0
# 2              Sim              Sim      Sim  Primípara       3075.0  2075.0
# 3              Não              Sim      Sim  Primípara       3505.0  2755.5
# 4              Não              Não      Sim   Nulípara       3405.0  2405.0
# ...            ...              ...      ...        ...          ...     ...
# 1703           Não              Sim      Sim  Primípara       2940.0  1940.0
# 1704           Não              Não      Sim  Primípara       1945.0   661.5
# 1705           Não              Não      Sim  Primípara       2275.0   892.5
# 1706           Não              Não      Sim   Nulípara       2590.0  1113.0
# 1707           Não              Sim      Sim  Multípara       3190.0  2190.0
#
#      PESO_ALTA BAIXO_APGAR5 PARTO_CESAREO
# 0       3440.0          Não           Não
# 1       2510.0          Não           Não
# 2       2925.0          Não           Não
# 3       3355.0          Não           Não
# 4       3255.0          Não           Não
# ...        ...          ...           ...
# 1703    2790.0          Não           Não
# 1704    1795.0          Não           Sim
# 1705    2125.0          Não           Sim
# 1706    2440.0          Não           Sim
# 1707    3040.0          Não           Não
#
# [1708 rows x 50 columns]

# %%
# informações sobre as variáveis/colunas
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1708 entries, 0 to 1707
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1708 non-null   int64
#  1   DT_INTERNACAO       1708 non-null   datetime64[ns]
#  2   DT_ALTA             1708 non-null   datetime64[ns]
#  3   DURACAO_INT         1708 non-null   int64
#  4   GESTACOES           1708 non-null   int64
#  5   PARTOS              1707 non-null   float64
#  6   IG_OBSTETRA         1686 non-null   float64
#  7   IG_PEDIATRA         1704 non-null   float64
#  8   ALTO_RISCO          1708 non-null   object
#  9   TIPO_PARTO          1708 non-null   object
#  10  HIPERTENSAO         1708 non-null   object
#  11  GEMELAR             1708 non-null   object
#  12  CESAREAS_PREVIAS    1701 non-null   float64
#  13  EPISIOTOMIA         1708 non-null   object
#  14  ANALGESIA           1708 non-null   object
#  15  FORCEPS             1708 non-null   object
#  16  CM_LACERACAO_CANAL  1553 non-null   object
#  17  CM_UTI              1708 non-null   object
#  18  CM_INFECCAO         1708 non-null   object
#  19  CM_NEARMISS         1708 non-null   object
#  20  CM_TRANSFUSAO       1705 non-null   object
#  21  VIVO                1672 non-null   object
#  22  SEXO                1650 non-null   object
#  23  PESO_NASCER         1680 non-null   float64
#  24  APGAR1              1650 non-null   float64
#  25  APGAR5              1708 non-null   int64
#  26  UTI_RN              1708 non-null   object
#  27  LIGADURACORDAO      605 non-null    object
#  28  LC_MOTIVO           53 non-null     object
#  29  EQUIPAMENTO_A       853 non-null    float64
#  30  EQUIPAMENTO_B       1708 non-null   float64
#  31  UBS                 1680 non-null   float64
#  32  BAIRRO              1708 non-null   object
#  33  LATITUDE            1708 non-null   float64
#  34  LONGITUDE           1708 non-null   float64
#  35  BAIXO_APGAR1        1650 non-null   object
#  36  ASFIXIA_APGAR1      1650 non-null   object
#  37  BAIXO_PESO          1680 non-null   object
#  38  PREMATURO_OBS       1686 non-null   object
#  39  PREMATURO_PED       1704 non-null   object
#  40  IG_TERMO            1686 non-null   object
#  41  HOUVE_CESAREA       1701 non-null   object
#  42  HOUVE_LACERACAO     1553 non-null   object
#  43  HOUVE_CM            1562 non-null   object
#  44  PARIDADE            1707 non-null   object
#  45  PESO_VIAVEIS        1640 non-null   float64
#  46  PESO_US             1595 non-null   float64
#  47  PESO_ALTA           1680 non-null   float64
#  48  BAIXO_APGAR5        1708 non-null   object
#  49  PARTO_CESAREO       1708 non-null   object
# dtypes: datetime64[ns](2), float64(14), int64(4), object(30)
# memory usage: 667.3+ KB

# %% [markdown]
# # Cálculo Amostral

# %%
# Cálculo amostral

# Função para fazer o cálculo amostral padrão para uma população heterogênia
def calculoAmostral(e, N):
    n = (N / (1 + (N*(e**2))))
    return (n)

# A fórmula de Slovin é uma equação geral que é utilizada quando precisamos
# estimar uma população mas não temos referência do comportamento dela.

# ****************************************************************
# Para usar a função informar o erro e a população estimados

# Erro amostral definido para o estudo
erro = 0.05

# População estimada para o estudo
populacao = 50000

# Cálculo da amostra
amostra = calculoAmostral(erro, populacao)

# arredondar o resultado para valores inteiros
round(amostra)
# Out:
# 397

# %% [markdown]
# Saiba mais: https://www.statisticshowto.com/probability-and-statistics/how-to-use-slovins-formula/
#
# Outras fórmulas: https://pt.wikihow.com/Calcular-o-Tamanho-de-uma-Amostra
#
# Informações sobre a Calculadora Amostral: https://comentto.com/calculadora-amostral/

# %% [markdown]
# # Amostra aleatória

# %%
# sample(N)
# Extrair uma amostra aleatória de 15 registros da base de dados

amostraAleatoria = dados.sample(15)

# Mostrar a amostra
amostraAleatoria
# Out:
#       Unnamed: 0 DT_INTERNACAO    DT_ALTA  DURACAO_INT  GESTACOES  PARTOS  \
# 24            24    2014-02-13 2014-02-14            1          3     0.0
# 318          318    2014-05-05 2014-05-06            1          1     0.0
# 160          160    2013-12-10 2013-12-11            1          6     2.0
# 451          451    2014-02-11 2014-02-13            2          2     1.0
# 506          506    2014-07-26 2014-07-28            2          1     0.0
# 749          749    2014-07-11 2014-07-13            2          2     1.0
# 656          656    2014-06-27 2014-06-29            2          2     0.0
# 174          174    2014-05-02 2014-05-03            1          3     2.0
# 549          549    2014-08-02 2014-08-04            2          1     0.0
# 93            93    2014-07-06 2014-07-07            1          1     0.0
# 870          870    2014-07-08 2014-07-10            2          5     4.0
# 684          684    2014-04-30 2014-05-02            2          2     1.0
# 1036        1036    2014-07-03 2014-07-05            2          6     5.0
# 1521        1521    2014-03-10 2014-03-14            4          2     1.0
# 985          985    2014-06-09 2014-06-11            2          2     1.0
#
#       IG_OBSTETRA  IG_PEDIATRA ALTO_RISCO     TIPO_PARTO  ...       IG_TERMO  \
# 24           40.0         40.0        Não   Parto Normal  ...          Termo
# 318          40.0         40.0        Não   Parto Normal  ...          Termo
# 160          37.0         37.0        Sim   Parto Normal  ...  Termo-precoce
# 451          37.0         37.0        Sim  Parto Cesáreo  ...  Termo-precoce
# 506          38.0         38.0        Não   Parto Normal  ...  Termo-precoce
# 749          41.0         41.0        Sim  Parto Cesáreo  ...          Termo
# 656          38.0         38.0        Não   Parto Normal  ...  Termo-precoce
# 174          38.0         38.0        Não   Parto Normal  ...  Termo-precoce
# 549          41.0         40.0        Sim   Parto Normal  ...          Termo
# 93           40.0         40.0        Não   Parto Normal  ...          Termo
# 870          39.0         39.0        Não  Parto Cesáreo  ...          Termo
# 684          40.0         40.0        Não  Parto Cesáreo  ...          Termo
# 1036         39.0         39.0        Não   Parto Normal  ...          Termo
# 1521         33.0         33.0        Sim  Parto Cesáreo  ...      Prematuro
# 985          40.0         40.0        Sim   Parto Normal  ...          Termo
#
#      HOUVE_CESAREA  HOUVE_LACERACAO HOUVE_CM   PARIDADE PESO_VIAVEIS PESO_US  \
# 24             Não              Não      Não   Nulípara       2720.0  1720.0
# 318            Não              Sim      Sim   Nulípara       3390.0  2390.0
# 160            Não              Sim      Sim  Multípara       2275.0  1275.0
# 451            Não              Não      Não  Primípara       3410.0  2410.0
# 506            Não              NaN      NaN   Nulípara       3270.0  2270.0
# 749            Sim              NaN      NaN  Primípara       3930.0  3223.0
# 656            Não              Não      Não   Nulípara       2970.0  1970.0
# 174            Não              Não      Não  Multípara       2800.0  1800.0
# 549            Não              Não      Não   Nulípara       3340.0  2574.0
# 93             Não              Sim      Sim   Nulípara       3320.0  2320.0
# 870            Sim              NaN      NaN  Multípara       3790.0  2790.0
# 684            Não              Não      Não  Primípara       3455.0  2455.0
# 1036           Não              Não      Não  Multípara       3070.0  2070.0
# 1521           Não              Não      Não  Primípara       1945.0   661.5
# 985            Sim              Sim      Sim  Primípara       3015.0  2015.0
#
#      PESO_ALTA BAIXO_APGAR5 PARTO_CESAREO
# 24      2570.0          Não           Não
# 318     3240.0          Não           Não
# 160     2125.0          Não           Não
# 451     3260.0          Não           Sim
# 506     3120.0          Não           Não
# 749     3780.0          Não           Sim
# 656     2820.0          Não           Não
# 174     2650.0          Não           Não
# 549     3190.0          Não           Não
# 93      3170.0          Não           Não
# 870     3640.0          Não           Sim
# 684     3305.0          Não           Sim
# 1036    2920.0          Não           Não
# 1521    1795.0          Não           Sim
# 985     2865.0          Não           Não
#
# [15 rows x 50 columns]

# %% [markdown]
# Saiba mais: https://www.delftstack.com/pt/api/python-pandas/pandas-dataframe-dataframe.sample-function/

# %% [markdown]
# # Amostragem Sistemática

# %%
# Amostragem Sistemática

# Definir o início e passo a passo da seleção de cada caso
inicio = 3
passo = 100

# arange(INICIO, TAMANHO, PASSO)
# criar uma lista com números de início a tamanho da base de dados de passo em passo

lista = np.arange(inicio, len(dados), step=passo)

# conferir lista de indices selecionados
print(lista)
# Out:
# [   3  103  203  303  403  503  603  703  803  903 1003 1103 1203 1303
#  1403 1503 1603 1703]

# %%
# seleciona na base de dados as linhas iguais aos indices selecionados
amostraSistematica = dados.iloc[lista]

# Mostrar os dados registros selecionados
amostraSistematica
# Out:
#       Unnamed: 0 DT_INTERNACAO    DT_ALTA  DURACAO_INT  GESTACOES  PARTOS  \
# 3              3    2013-12-04 2013-12-05            1          2     1.0
# 103          103    2014-08-21 2014-08-22            1          2     1.0
# 203          203    2013-12-09 2013-12-10            1          1     0.0
# 303          303    2014-10-28 2014-10-30            1          2     1.0
# 403          403    2014-02-06 2014-02-07            2          1     0.0
# 503          503    2014-03-19 2014-03-21            2          2     1.0
# 603          603    2014-07-24 2014-07-26            2          1     0.0
# 703          703    2014-02-07 2014-02-09            2          2     1.0
# 803          803    2014-06-12 2014-06-14            2          2     1.0
# 903          903    2014-05-28 2014-05-30            2          2     1.0
# 1003        1003    2014-01-17 2014-01-19            2          3     2.0
# 1103        1103    2013-10-05 2013-10-07            2          1     0.0
# 1203        1203    2014-02-18 2014-02-21            3          1     0.0
# 1303        1303    2014-02-19 2014-02-22            3          2     1.0
# 1403        1403    2013-12-20 2013-12-23            3          4     3.0
# 1503        1503    2014-06-28 2014-07-02            4          1     0.0
# 1603        1603    2014-07-28 2014-08-03            6          6     1.0
# 1703        1703    2014-07-05 2014-08-12           38          2     1.0
#
#       IG_OBSTETRA  IG_PEDIATRA ALTO_RISCO     TIPO_PARTO  ...       IG_TERMO  \
# 3            41.0         41.0        Não   Parto Normal  ...          Termo
# 103          40.0         40.0        Não   Parto Normal  ...          Termo
# 203          38.0         38.0        Sim   Parto Normal  ...  Termo-precoce
# 303          39.0         39.0        Não   Parto Normal  ...          Termo
# 403          41.0         41.0        Não   Parto Normal  ...          Termo
# 503          40.0         40.0        Não  Parto Cesáreo  ...          Termo
# 603          39.0         40.0        Sim   Parto Normal  ...          Termo
# 703          40.0         40.0        Não   Parto Normal  ...          Termo
# 803          41.0         40.0        Sim   Parto Normal  ...          Termo
# 903          40.0         40.0        Não  Parto Cesáreo  ...          Termo
# 1003         37.0         37.0        Não   Parto Normal  ...  Termo-precoce
# 1103         39.0         39.0        Não  Parto Cesáreo  ...          Termo
# 1203         36.0         36.0        Sim   Parto Normal  ...      Prematuro
# 1303         40.0         40.0        Não  Parto Cesáreo  ...          Termo
# 1403         38.0         38.0        Não  Parto Cesáreo  ...  Termo-precoce
# 1503         40.0         41.0        Sim   Parto Normal  ...          Termo
# 1603         37.0         37.0        Sim  Parto Cesáreo  ...  Termo-precoce
# 1703         38.0         38.0        Não   Parto Normal  ...  Termo-precoce
#
#      HOUVE_CESAREA  HOUVE_LACERACAO HOUVE_CM   PARIDADE PESO_VIAVEIS PESO_US  \
# 3              Não              Sim      Sim  Primípara       3505.0  2755.5
# 103            Não              Sim      Sim  Primípara       2850.0  1850.0
# 203            Não              Não      Não   Nulípara       2815.0  1815.0
# 303            Não              Não      Não  Primípara       3110.0  2110.0
# 403            Não              Não      Não   Nulípara       3460.0  2706.0
# 503            Sim              Não      Não  Primípara       3415.0  2415.0
# 603            Não              Sim      Sim   Nulípara       2595.0  1595.0
# 703            Não              Não      Não  Primípara       3025.0  2025.0
# 803            Não              Não      Não  Primípara       3310.0  2541.0
# 903            Sim              Não      Não  Primípara          NaN     NaN
# 1003           Não              Não      Não  Multípara       3355.0  2355.0
# 1103           Não              Não      Não   Nulípara       3240.0  2240.0
# 1203           Não              Não      Não   Nulípara       3025.0  2025.0
# 1303           Sim              Não      Não  Primípara       3075.0  2075.0
# 1403           Não              Não      Não  Multípara       2885.0  1885.0
# 1503           Não              Não      Não   Nulípara       2770.0  1770.0
# 1603           Não              NaN      NaN  Primípara       3130.0  2130.0
# 1703           Não              Sim      Sim  Primípara       2940.0  1940.0
#
#      PESO_ALTA BAIXO_APGAR5 PARTO_CESAREO
# 3       3355.0          Não           Não
# 103     2700.0          Não           Não
# 203     2665.0          Não           Não
# 303     2960.0          Não           Não
# 403     3310.0          Não           Não
# 503     3265.0          Não           Sim
# 603     2445.0          Não           Não
# 703     2875.0          Não           Não
# 803     3160.0          Não           Não
# 903        NaN          Não           Sim
# 1003    3205.0          Não           Não
# 1103    3090.0          Não           Sim
# 1203    2875.0          Não           Não
# 1303    2925.0          Não           Sim
# 1403    2735.0          Não           Sim
# 1503    2620.0          Sim           Não
# 1603    2980.0          Não           Sim
# 1703    2790.0          Não           Não
#
# [18 rows x 50 columns]

# %% [markdown]
# # Amostragem Estratificada

# %%
# Importação das bibliotecas: StratifiedShuffleSplit para divisão da base de dados (separar amostras)
from sklearn.model_selection import StratifiedShuffleSplit

# %%
# Para relembrar como a base está distribuída por ALTO_RISCO
# Nos dados: 53.1% não tem alto risco e 46.9% tem alto risco

dados.ALTO_RISCO.value_counts(normalize=True)
# Out:
# ALTO_RISCO
# Não    0.53103
# Sim    0.46897
# Name: proportion, dtype: float64

# %%
# Amostragem estratificada por ALTO_RISCO

# tamanho da amostra de 20% do total da base de dados
tamanhoAmostra = 0.2

split = StratifiedShuffleSplit(test_size = tamanhoAmostra)

for x, y in split.split(dados, dados.ALTO_RISCO):
  df_x = dados.iloc[x]
  df_y = dados.iloc[y]

# df_y é a AMOSTRA ESTRATIFICADA por ALTO_RISCO, com 20% dados balanceados por ALTO_RISCO
df_y

# df_x ficou com o restante dos 80% dos dados
# Out:
#       Unnamed: 0 DT_INTERNACAO    DT_ALTA  DURACAO_INT  GESTACOES  PARTOS  \
# 1072        1072    2013-12-31 2014-01-03            2          1     0.0
# 439          439    2014-02-11 2014-02-13            2          3     1.0
# 1671        1671    2013-11-12 2013-11-24           12          1     0.0
# 968          968    2014-10-19 2014-10-21            2          2     1.0
# 1667        1667    2013-11-06 2013-11-18           12          3     2.0
# ...          ...           ...        ...          ...        ...     ...
# 495          495    2014-03-19 2014-03-21            2          1     0.0
# 1023        1023    2013-10-07 2013-10-09            2          3     1.0
# 883          883    2014-03-22 2014-03-24            2          2     1.0
# 82            82    2013-12-14 2013-12-15            1          1     0.0
# 213          213    2014-05-08 2014-05-09            1          1     0.0
#
#       IG_OBSTETRA  IG_PEDIATRA ALTO_RISCO     TIPO_PARTO  ...       IG_TERMO  \
# 1072         39.0         39.0        Não  Parto Cesáreo  ...          Termo
# 439          39.0         39.0        Sim   Parto Normal  ...          Termo
# 1671         36.0         38.0        Sim   Parto Normal  ...      Prematuro
# 968          39.0         39.0        Sim  Parto Cesáreo  ...          Termo
# 1667         32.0         34.0        Sim  Parto Cesáreo  ...      Prematuro
# ...           ...          ...        ...            ...  ...            ...
# 495          35.0         39.0        Sim   Parto Normal  ...      Prematuro
# 1023         38.0         38.0        Não   Parto Normal  ...  Termo-precoce
# 883          38.0         38.0        Não  Parto Cesáreo  ...  Termo-precoce
# 82           40.0         39.0        Não   Parto Normal  ...          Termo
# 213          40.0         40.0        Não   Parto Normal  ...          Termo
#
#      HOUVE_CESAREA  HOUVE_LACERACAO HOUVE_CM   PARIDADE PESO_VIAVEIS PESO_US  \
# 1072           Não              Não      Não   Nulípara       3165.0  2165.0
# 439            Não              Sim      Sim  Primípara       3540.0  2540.0
# 1671           Não              Sim      Sim   Nulípara       2880.0  1880.0
# 968            Sim              NaN      NaN  Primípara       3300.0  2300.0
# 1667           Sim              Não      Não  Multípara       2390.0   973.0
# ...            ...              ...      ...        ...          ...     ...
# 495            Não              Sim      Sim   Nulípara          NaN     NaN
# 1023           Não              Sim      Sim  Primípara       2975.0  1975.0
# 883            Não              Não      Não  Primípara       3410.0  2410.0
# 82             Não              Não      Não   Nulípara       3230.0  2230.0
# 213            Não              Sim      Sim   Nulípara       2865.0  1865.0
#
#      PESO_ALTA BAIXO_APGAR5 PARTO_CESAREO
# 1072    3015.0          Não           Sim
# 439     3390.0          Não           Não
# 1671    2730.0          Não           Não
# 968     3150.0          Não           Sim
# 1667    2240.0          Não           Sim
# ...        ...          ...           ...
# 495     1555.0          Sim           Não
# 1023    2825.0          Não           Não
# 883     3260.0          Não           Sim
# 82      3080.0          Não           Não
# 213     2715.0          Não           Não
#
# [342 rows x 50 columns]

# %%
# Para conferir se o estrato manteve-se com as mesmas porcentagems de ALTO_RISCO
# Nos dados: 53.1% não tem alto risco e 46.9% tem alto risco
# Nos 20%:   53.2% não tem alto risco e 46.8% tem alto risco

df_y.ALTO_RISCO.value_counts(normalize=True)
# Out:
# ALTO_RISCO
# Não    0.532164
# Sim    0.467836
# Name: proportion, dtype: float64
